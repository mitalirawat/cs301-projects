# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json

# %%
# question1 - write a function to get the data from a file "filename" at url "url" 
#- check the contents of this file- u will see that they are names of some json file
#send a get request on each of these json files and collect the result as a list of dictionaries
#load the dict into a dataframe
# process countries data
def get_data_from_file(url, filename):
    r = requests.get(url+filename)
    filelist = r.text
    #print(filelist)
    data_list = []
    url_list = filelist.split('\n')
    #print(url_list)
    for file in url_list:
        if file =="":
            continue
        resp = requests.get(url+file)
        #either add to dict or to dataframe
        d = json.loads(resp.text)
        data_list.append(d)
    cntry_data = pd.DataFrame.from_dict(data_list)
    return cntry_data

# %%
# Q2- write a function to get data from the given two urls and file names
country_data = get_data_from_file("http://localhost:8082/Capitals_with_Data/", "file_list.txt")
country_capitals = get_data_from_file("http://localhost:8082/Countries_with_Capitals/", "file_list.txt")

# %%
# country_data = pd.read_csv('capitals_and_data.csv')
# country_capitals = pd.read_csv('country-capitals.csv')

# %%
country_data
# Out:
#     Area (sq. mi.) Birthrate      Capital City Coastline (coast/area ratio)  \
# 0           647500      46,6             Kabul                         0,00
# 1            28748     15,11            Tirana                         1,26
# 2          2381740     17,14           Algiers                         0,04
# 3              199     22,46         Pago Pago                        58,29
# 4              468      8,71  Andorra la Vella                         0,00
# 5          1246700     45,11            Luanda                         0,13
# 6              102     14,17        The Valley                        59,80
# 7          2766890     16,73      Buenos Aires                         0,18
# 8            29800     12,07           Yerevan                         0,00
# 9              193     11,03        Oranjestad                        35,49
# 10         7686850     12,14          Canberra                         0,34
# 11           83870      8,74            Vienna                         0,00
# 12           86600     20,74              Baku                         0,00
# 13             665      17,8            Manama                        24,21
# 14          144000      29,8             Dhaka                         0,40
# 15             431     12,71        Bridgetown                        22,51
# 16          207600     11,16             Minsk                         0,00
# 17           30528     10,38          Brussels                         0,22
# 18           22966     28,84          Belmopan                         1,68
# 19          112620     38,85        Porto-Novo                         0,11
# 20              53      11,4          Hamilton                       194,34
# 21           47000     33,65           Thimphu                         0,00
# 22         1098580      23,3            La Paz                         0,00
# 23          600370     23,08          Gaborone                         0,00
# 24         8511965     16,56          Brasilia                         0,09
# 25          110910      9,65             Sofia                         0,32
# 26          274200     45,62       Ouagadougou                         0,00
# 27           27830     42,22         Bujumbura                         0,00
# 28          181040      26,9        Phnom Penh                         0,24
# 29          475440     33,89           Yaounde                         0,08
# ..             ...       ...               ...                          ...
# 150          98480        10             Seoul                         2,45
# 151          65610     15,51           Colombo                         2,04
# 152        2505810     34,53          Khartoum                         0,03
# 153         163270     18,02        Paramaribo                         0,24
# 154          17363     27,41           Mbabane                         0,00
# 155         449964     10,27         Stockholm                         0,72
# 156          41290      9,71              Bern                         0,00
# 157         185180     27,76          Damascus                         0,10
# 158          35980     12,56            Taipei                         4,35
# 159         143100     32,65          Dushanbe                         0,00
# 160         945087     37,71     Dar es Salaam                         0,15
# 161         514000     13,87           Bangkok                         0,63
# 162          56785     37,01              Lome                         0,10
# 163            748     25,37        Nuku'alofa                        56,02
# 164         163610     15,52             Tunis                         0,70
# 165         780580     16,62            Ankara                         0,92
# 166         488100     27,61          Ashgabat                         0,00
# 167         236040     47,35           Kampala                         0,00
# 168         603700      8,82              Kyiv                         0,46
# 169          82880     18,96         Abu Dhabi                         1,59
# 170         244820     10,71            London                         5,08
# 171        9631420     14,14   Washington D.C.                         0,21
# 172         176220     13,91        Montevideo                         0,37
# 173         447400     26,36          Tashkent                         0,00
# 174          12200     22,72         Port-Vila                        20,72
# 175         912050     18,71           Caracas                         0,31
# 176         329560     16,86             Hanoi                         1,05
# 177         527970     42,89             Sanaa                         0,36
# 178         752614        41            Lusaka                         0,00
# 179         390580     28,01            Harare                         0,00
#
#     Deathrate GDP ($ per capita) Infant mortality (per 1000 births)  \
# 0       20,34              700.0                             163,07
# 1        5,22             4500.0                              21,52
# 2        4,61             6000.0                                 31
# 3        3,27             8000.0                               9,27
# 4        6,25            19000.0                               4,05
# 5        24,2             1900.0                             191,19
# 6        5,34             8600.0                              21,03
# 7        7,55            11200.0                              15,18
# 8        8,23             3500.0                              23,28
# 9        6,68            28000.0                               5,89
# 10       7,51            29000.0                               4,69
# 11       9,76            30000.0                               4,66
# 12       9,75             3400.0                              81,74
# 13       4,14            16900.0                              17,27
# 14       8,27             1900.0                               62,6
# 15       8,67            15700.0                               12,5
# 16      14,02             6100.0                              13,37
# 17      10,27            29100.0                               4,68
# 18       5,72             4900.0                              25,69
# 19      12,22             1100.0                                 85
# 20       7,74            36000.0                               8,53
# 21       12,7             1300.0                             100,44
# 22       7,53             2400.0                              53,11
# 23       29,5             9000.0                              54,58
# 24       6,17             7600.0                              29,61
# 25      14,27             7600.0                              20,55
# 26       15,6             1100.0                              97,57
# 27      13,46              600.0                              69,29
# 28       9,06             1900.0                              71,48
# 29      13,47             1800.0                              68,26
# ..        ...                ...                                ...
# 150      5,85              17800                               7,05
# 151      6,52             3700.0                              14,35
# 152      8,97             1900.0                               62,5
# 153      7,27             4000.0                              23,57
# 154     29,74             4900.0                              69,27
# 155     10,31            26800.0                               2,77
# 156      8,49            32700.0                               4,39
# 157      4,81             3300.0                              29,53
# 158      6,48            23400.0                                6,4
# 159      8,25             1000.0                             110,76
# 160     16,39              600.0                              98,54
# 161      7,04             7400.0                              20,48
# 162      9,83             1500.0                              66,61
# 163      5,28             2200.0                              12,62
# 164      5,13             6900.0                              24,77
# 165      5,97             6700.0                              41,04
# 166       8,6             5800.0                              73,08
# 167     12,24             1400.0                              67,83
# 168     14,39             5400.0                              20,34
# 169       4,4            23200.0                              14,51
# 170     10,13            27700.0                               5,16
# 171      8,26            37800.0                                6,5
# 172      9,05            12800.0                              11,95
# 173      7,84             1700.0                               71,1
# 174      7,82             2900.0                              55,16
# 175      4,92             4800.0                               22,2
# 176      6,22             2500.0                              25,95
# 177       8,3              800.0                               61,5
# 178     19,93              800.0                              88,29
# 179     21,84             1900.0                              67,69
#
#     Literacy rate Net migration Phones (per 1000) Pop. Density (per sq. mi.)  \
# 0            36,0         23,06               3,2                       48,0
# 1            86,5         -4,93              71,2                      124,6
# 2            70,0         -0,39              78,1                       13,8
# 3            97,0        -20,71             259,5                      290,4
# 4           100,0           6,6             497,2                      152,1
# 5            42,0             0               7,8                        9,7
# 6            95,0         10,76             460,0                      132,1
# 7            97,1          0,61             220,4                       14,4
# 8            98,6         -6,47             195,7                       99,9
# 9            97,0             0             516,1                      372,5
# 10          100,0          3,98             565,5                        2,6
# 11           98,0             2             452,2                       97,7
# 12           97,0          -4,9             137,1                       91,9
# 13           89,1          1,05             281,3                     1050,5
# 14           43,1         -0,71               7,3                     1023,4
# 15           97,4         -0,31             481,9                      649,5
# 16           99,6          2,54             319,1                       49,6
# 17           98,0          1,23             462,6                      340,0
# 18           94,1             0             115,7                       12,5
# 19           40,9             0               9,7                       69,8
# 20           98,0          2,49             851,4                     1241,0
# 21           42,2             0              14,3                       48,5
# 22           87,2         -1,32              71,9                        8,2
# 23           79,8             0              80,5                        2,7
# 24           86,4         -0,03             225,3                       22,1
# 25           98,6         -4,58             336,3                       66,6
# 26           26,6             0               7,0                       50,7
# 27           51,6         -0,06               3,4                      290,7
# 28           69,4             0               2,6                       76,7
# 29           79,0             0               5,7                       36,5
# ..            ...           ...               ...                        ...
# 150          97,9             0             486,1                      496,0
# 151          92,3         -1,31              61,5                      308,2
# 152          61,1         -0,02              16,3                       16,5
# 153          93,0         -8,81             184,7                        2,7
# 154          81,6             0              30,8                       65,5
# 155          99,0          1,67             715,0                       20,0
# 156          99,0          4,05             680,9                      182,2
# 157          76,9             0             153,8                      102,0
# 158          96,1             0             591,0                      640,3
# 159          99,4         -2,86              33,5                       51,2
# 160          78,2         -2,06               4,0                       39,6
# 161          92,6             0             108,9                      125,7
# 162          60,9             0              10,6                       97,7
# 163          98,5             0              97,7                      153,3
# 164          74,2         -0,57             123,6                       62,2
# 165          86,5             0             269,5                       90,2
# 166          98,0         -0,86              74,6                       10,3
# 167          69,9             0               3,6                      119,5
# 168          99,7         -0,39             259,9                       77,4
# 169          77,9          1,03             475,3                       31,4
# 170          99,0          2,19             543,5                      247,6
# 171          97,0          3,41             898,0                       31,0
# 172          98,0         -0,32             291,4                       19,5
# 173          99,3         -1,72              62,9                       61,0
# 174          53,0             0              32,6                       17,1
# 175          93,4         -0,04             140,1                       28,2
# 176          90,3         -0,45             187,7                      256,1
# 177          50,2             0              37,2                       40,6
# 178          80,6             0               8,2                       15,3
# 179          90,7             0              26,8                       31,3
#
#     Population                Region
# 0     31056997  ASIA (EX. NEAR EAST)
# 1      3581655        EASTERN EUROPE
# 2     32930091       NORTHERN AFRICA
# 3        57794               OCEANIA
# 4        71201        WESTERN EUROPE
# 5     12127071    SUB-SAHARAN AFRICA
# 6        13477   LATIN AMER. & CARIB
# 7     39921833   LATIN AMER. & CARIB
# 8      2976372   C.W. OF IND. STATES
# 9        71891   LATIN AMER. & CARIB
# 10    20264082               OCEANIA
# 11     8192880        WESTERN EUROPE
# 12     7961619   C.W. OF IND. STATES
# 13      698585             NEAR EAST
# 14   147365352  ASIA (EX. NEAR EAST)
# 15      279912   LATIN AMER. & CARIB
# 16    10293011   C.W. OF IND. STATES
# 17    10379067        WESTERN EUROPE
# 18      287730   LATIN AMER. & CARIB
# 19     7862944    SUB-SAHARAN AFRICA
# 20       65773      NORTHERN AMERICA
# 21     2279723  ASIA (EX. NEAR EAST)
# 22     8989046   LATIN AMER. & CARIB
# 23     1639833    SUB-SAHARAN AFRICA
# 24   188078227   LATIN AMER. & CARIB
# 25     7385367        EASTERN EUROPE
# 26    13902972    SUB-SAHARAN AFRICA
# 27     8090068    SUB-SAHARAN AFRICA
# 28    13881427  ASIA (EX. NEAR EAST)
# 29    17340702    SUB-SAHARAN AFRICA
# ..         ...                   ...
# 150   48846823  ASIA (EX. NEAR EAST)
# 151   20222240  ASIA (EX. NEAR EAST)
# 152   41236378    SUB-SAHARAN AFRICA
# 153     439117   LATIN AMER. & CARIB
# 154    1136334    SUB-SAHARAN AFRICA
# 155    9016596        WESTERN EUROPE
# 156    7523934        WESTERN EUROPE
# 157   18881361             NEAR EAST
# 158   23036087  ASIA (EX. NEAR EAST)
# 159    7320815   C.W. OF IND. STATES
# 160   37445392    SUB-SAHARAN AFRICA
# 161   64631595  ASIA (EX. NEAR EAST)
# 162    5548702    SUB-SAHARAN AFRICA
# 163     114689               OCEANIA
# 164   10175014       NORTHERN AFRICA
# 165   70413958             NEAR EAST
# 166    5042920   C.W. OF IND. STATES
# 167   28195754    SUB-SAHARAN AFRICA
# 168   46710816   C.W. OF IND. STATES
# 169    2602713             NEAR EAST
# 170   60609153        WESTERN EUROPE
# 171  298444215      NORTHERN AMERICA
# 172    3431932   LATIN AMER. & CARIB
# 173   27307134   C.W. OF IND. STATES
# 174     208869               OCEANIA
# 175   25730435   LATIN AMER. & CARIB
# 176   84402966  ASIA (EX. NEAR EAST)
# 177   21456188             NEAR EAST
# 178   11502010    SUB-SAHARAN AFRICA
# 179   12236805    SUB-SAHARAN AFRICA
#
# [180 rows x 13 columns]

# %%
country_capitals
# Out:
#                Capital     Capital Latitude    Captial Longitude  \
# 0             Hargeisa                 9.55                44.05
# 1    King Edward Point           -54.283333                -36.5
# 2    Port-aux-Français               -49.35            70.216667
# 3            Mariehamn    60.11666700000001                 19.9
# 4                Yaren              -0.5477           166.920867
# 5              Marigot              18.0731             -63.0822
# 6                Atafu            -9.166667          -171.833333
# 7             El-Aaiún   27.153610999999998  -13.203332999999999
# 8                Kabul   34.516666666666666    69.18333299999999
# 9               Tirana    41.31666666666667   19.816667000000002
# 10             Algiers                36.75                 3.05
# 11           Pago Pago  -14.266666666666667               -170.7
# 12    Andorra la Vella                 42.5             1.516667
# 23              Asia                                   Bahrain
# 24              Asia                                Bangladesh
# 25     North America                                  Barbados
# 26            Europe                                   Belarus
# 27            Europe                                   Belgium
# 28   Central America                                    Belize
# 29            Africa                                     Benin
# ..               ...                                       ...
# 208             Asia                                    Taiwan
# 209             Asia                                Tajikistan
# 210           Africa                                  Tanzania
# 211             Asia                                  Thailand
# 212             Asia                               Timor-Leste
# 213           Africa                                      Togo
# 214        Australia                                     Tonga
# 215    North America                       Trinidad and Tobago
# 216           Africa                                   Tunisia
# 217           Europe                                    Turkey
# 218             Asia                              Turkmenistan
# 219    North America                  Turks and Caicos Islands
# 220        Australia                                    Tuvalu
# 221           Africa                                    Uganda
# 222           Europe                                   Ukraine
# 223             Asia                      United Arab Emirates
# 224           Europe                            United Kingdom
# 225  Central America                             United States
# 226    South America                                   Uruguay
# 227             Asia                                Uzbekistan
# 228        Australia                                   Vanuatu
# 229    South America                                 Venezuela
# 230             Asia                                   Vietnam
# 231    North America                         US Virgin Islands
# 232        Australia                         Wallis and Futuna
# 233             Asia                                     Yemen
# 234           Africa                                    Zambia
# 235           Africa                                  Zimbabwe
# 236           Europe                           Northern Cyprus
# 237           Africa            British Indian Ocean Territory
#
# [238 rows x 5 columns]

# %%
# Q-3 Write a function to clean the 2 dataframes
# Rename column - "Captial Longitude" to "Capital Longitude"
# delete the region column
country_capitals.rename(columns={'Captial Longitude':'Capital Longitude'}, inplace=True)
country_data = country_data.drop(columns=['Region','Phones (per 1000)' ])

# %%
#Also many columns contains commas (,) instead of (.) decimal points- fix so that the data is a a valid decimal number
country_data['Literacy rate'] = country_data['Literacy rate'].str.replace(',', '.')
#lit = [float((k).replace(',','.')) for k in list(country_data['Literacy rate'])]
country_data['Birthrate'] = country_data['Birthrate'].str.replace(',', '.')
country_data['Deathrate'] = country_data['Deathrate'].str.replace(',', '.')
country_data['Coastline (coast/area ratio)'] = country_data['Coastline (coast/area ratio)'].str.replace(',', '.')
country_data['Infant mortality (per 1000 births)'] = country_data['Infant mortality (per 1000 births)'].str.replace(',', '.')
country_data
# Out:
#     Area (sq. mi.) Birthrate           Capital Coastline (coast/area ratio)  \
# 0           647500      46.6             Kabul                         0.00
# 1            28748     15.11            Tirana                         1.26
# 2          2381740     17.14           Algiers                         0.04
# 3              199     22.46         Pago Pago                        58.29
# 4              468      8.71  Andorra la Vella                         0.00
# 5          1246700     45.11            Luanda                         0.13
# 6              102     14.17        The Valley                        59.80
# 7          2766890     16.73      Buenos Aires                         0.18
# 8            29800     12.07           Yerevan                         0.00
# 9              193     11.03        Oranjestad                        35.49
# 10         7686850     12.14          Canberra                         0.34
# 11           83870      8.74            Vienna                         0.00
# 12           86600     20.74              Baku                         0.00
# 13             665      17.8            Manama                        24.21
# 14          144000      29.8             Dhaka                         0.40
# 15             431     12.71        Bridgetown                        22.51
# 16          207600     11.16             Minsk                         0.00
# 17           30528     10.38          Brussels                         0.22
# 18           22966     28.84          Belmopan                         1.68
# 19          112620     38.85        Porto-Novo                         0.11
# 20              53      11.4          Hamilton                       194.34
# 21           47000     33.65           Thimphu                         0.00
# 22         1098580      23.3            La Paz                         0.00
# 23          600370     23.08          Gaborone                         0.00
# 24         8511965     16.56          Brasilia                         0.09
# 25          110910      9.65             Sofia                         0.32
# 26          274200     45.62       Ouagadougou                         0.00
# 27           27830     42.22         Bujumbura                         0.00
# 28          181040      26.9        Phnom Penh                         0.24
# 29          475440     33.89           Yaounde                         0.08
# ..             ...       ...               ...                          ...
# 150          98480        10             Seoul                         2.45
# 151          65610     15.51           Colombo                         2.04
# 152        2505810     34.53          Khartoum                         0.03
# 153         163270     18.02        Paramaribo                         0.24
# 154          17363     27.41           Mbabane                         0.00
# 155         449964     10.27         Stockholm                         0.72
# 156          41290      9.71              Bern                         0.00
# 157         185180     27.76          Damascus                         0.10
# 158          35980     12.56            Taipei                         4.35
# 159         143100     32.65          Dushanbe                         0.00
# 160         945087     37.71     Dar es Salaam                         0.15
# 161         514000     13.87           Bangkok                         0.63
# 162          56785     37.01              Lome                         0.10
# 163            748     25.37        Nuku'alofa                        56.02
# 164         163610     15.52             Tunis                         0.70
# 165         780580     16.62            Ankara                         0.92
# 166         488100     27.61          Ashgabat                         0.00
# 167         236040     47.35           Kampala                         0.00
# 168         603700      8.82              Kyiv                         0.46
# 169          82880     18.96         Abu Dhabi                         1.59
# 170         244820     10.71            London                         5.08
# 171        9631420     14.14   Washington D.C.                         0.21
# 172         176220     13.91        Montevideo                         0.37
# 173         447400     26.36          Tashkent                         0.00
# 174          12200     22.72         Port-Vila                        20.72
# 175         912050     18.71           Caracas                         0.31
# 176         329560     16.86             Hanoi                         1.05
# 177         527970     42.89             Sanaa                         0.36
# 178         752614        41            Lusaka                         0.00
# 179         390580     28.01            Harare                         0.00
#
#     Deathrate GDP ($ per capita) Infant mortality (per 1000 births)  \
# 0       20.34              700.0                             163.07
# 1        5.22             4500.0                              21.52
# 2        4.61             6000.0                                 31
# 3        3.27             8000.0                               9.27
# 4        6.25            19000.0                               4.05
# 5        24.2             1900.0                             191.19
# 6        5.34             8600.0                              21.03
# 7        7.55            11200.0                              15.18
# 8        8.23             3500.0                              23.28
# 9        6.68            28000.0                               5.89
# 10       7.51            29000.0                               4.69
# 11       9.76            30000.0                               4.66
# 12       9.75             3400.0                              81.74
# 13       4.14            16900.0                              17.27
# 14       8.27             1900.0                               62.6
# 15       8.67            15700.0                               12.5
# 16      14.02             6100.0                              13.37
# 17      10.27            29100.0                               4.68
# 18       5.72             4900.0                              25.69
# 19      12.22             1100.0                                 85
# 20       7.74            36000.0                               8.53
# 21       12.7             1300.0                             100.44
# 22       7.53             2400.0                              53.11
# 23       29.5             9000.0                              54.58
# 24       6.17             7600.0                              29.61
# 25      14.27             7600.0                              20.55
# 26       15.6             1100.0                              97.57
# 160          78.2         -2,06                       39,6   37445392
# 161          92.6             0                      125,7   64631595
# 162          60.9             0                       97,7    5548702
# 163          98.5             0                      153,3     114689
# 164          74.2         -0,57                       62,2   10175014
# 165          86.5             0                       90,2   70413958
# 166          98.0         -0,86                       10,3    5042920
# 167          69.9             0                      119,5   28195754
# 168          99.7         -0,39                       77,4   46710816
# 169          77.9          1,03                       31,4    2602713
# 170          99.0          2,19                      247,6   60609153
# 171          97.0          3,41                       31,0  298444215
# 172          98.0         -0,32                       19,5    3431932
# 173          99.3         -1,72                       61,0   27307134
# 174          53.0             0                       17,1     208869
# 175          93.4         -0,04                       28,2   25730435
# 176          90.3         -0,45                      256,1   84402966
# 177          50.2             0                       40,6   21456188
# 178          80.6             0                       15,3   11502010
# 179          90.7             0                       31,3   12236805
#
# [180 rows x 11 columns]

# %%
# Convert all numerical columns to float except population
country_data = country_data.astype({"Area (sq. mi.)": float,
                                    "Birthrate": float, "Coastline (coast/area ratio)": float, "Deathrate":float,
                                    "GDP ($ per capita)":float, "Infant mortality (per 1000 births)": float,
                                    "Literacy rate": float, "Population":int})
country_capitals = country_capitals.astype({"Capital Latitude":float,"Capital Longitude":float})

# %% [markdown]
# ## merge the two datasets using pandas
# * needs renaming Capital City column to Capital

# %%
#Q-4 merge the two dataframes based on the name of the capital in both datasets
country_data.rename(columns={'Capital City':'Capital'}, inplace=True)
result = pd.merge(country_capitals, country_data, on='Capital', how='inner', validate=None)
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-203d299227d9> in <module>()
#       1 #Q-4 merge the two dataframes based on the name of the capital in both datasets
# ----> 2 country_data.rename(columns={'Capital City':'Capital'}, inplace=True)
#       3 result = pd.merge(country_capitals, country_data, on='Capital', how='inner', validate=None)
#       4 result
#
# NameError: name 'country_data' is not defined

# %%
#Q-5 output all rows whose population is < threshold or output names of all countries as a list whose pop is less than 10000

a = result[result.Population< 100000]
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c1d5d483a3a6> in <module>()
#       1 #Q-5 output all rows whose population is < threshold or output names of all countries as a list whose pop is less than 10000
#       2
# ----> 3 a = result[result.Population< 100000]
#       4 a
#
# NameError: name 'result' is not defined

# %% [markdown]
# ## find properties in the data using Pandas
# * mean and standard deviation of literacy
# * correlation coefficient between GDP and literacy

# %%
#Q-6 find the mean, std dev of literacy across all countries
#statistical properties of data- mean and std dev
lit = result['Literacy rate']

# %%
m = lit.mean()
s = lit.std()
# Out:
# 20.17855764673653

# %%
gdp  = result['GDP ($ per capita)']

# %%
#Q-7 find the correlation coefficient between gdp and literacy across all countries
c = gdp.corr(lit)
c
# Out:
# 0.5162204543369631

# %% [markdown]
# Plotting
# * Plot histogram of GDP
# * Plot histogram of literacy
# * scatter plot of literacy vs GDP

# %%
plt.hist(result['GDP ($ per capita)'],  edgecolor ='w')
plt.show()

# %%
plt.hist(lit, color = 'b', edgecolor ='w')
plt.show()

# %%
plt.scatter(lit, gdp)
plt.xlabel('Literacy rate')
plt.ylabel('GDP')
plt.show()
